# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">문제 해결과 프로그래밍</div>
#     <div style="font-weight: bold; font-size: 20px">1. 추상화</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     &#x2022; 문제의 이해와 추상화 <br>
#     &#x2022; 문제 분석과 핵심 요소 추출<br>
#     &#x2022; 문제 분해와 모델링<br>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 생각해보기</div>
#     <br>
# 우리는 현실 문제 해결을 위해 필요한 요소를 파악하고 그것을 단순화하여 표현한다. 이러한 표현물에는 어떤 것들이 있을까?
# </div>

# %% [markdown]
# ![image.png](attachment:e8780cb7-af31-4a0c-bd63-ad72192a932e.png)

# %% [markdown]
# **일반화된 지식**
# ✏️ 추상화는 문제를 이해하고 분석하여 문제 해결에 필요한 부분을 추출하여 이해하고 다루기 쉽게 만드는 과정이다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 문제의 이해와 추상화</h2>
#     &emsp;&#x2022; 문제 상황과 관련해 현재 상태와 목표 상태 사이의 차이를 설명할 수 있다. <br>
#     &emsp;&#x2022; 추상화가 문제 해결 활동에 어떤 실질적 유익을 주는지 설명할 수 있다.<br>
# </div>

# %% [markdown]
# ### **(1) 문제의 이해**

# %% [markdown]
# ![image.png](attachment:5cca79a6-f384-4473-99da-a8d67f170cce.png)

# %% [markdown]
# ### **(2) 추상화 개념**

# %% [markdown]
# ![image.png](attachment:22b94e82-287a-4ec6-81e2-511f841b1df8.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">🤓 개인 활동:</div>
#     <div style="font-weight: bold; font-size: 17px"> &emsp;문제 상황을 추상화한 사례 조사하기</div>
#     <br>
#     <div style="font-weight: normal; font-size: 14px"> 우리 주변의 사물을 보면 문제를 이해하고 추상화한 것들이 매우 많다. 주변에서 문제 상황을 단순화시켜 추상화한 사례를 조사해 보자.</div>
#
# </div>

# %% [markdown]
# ![image.png](attachment:4ac5c996-2c3f-42e5-a417-4f311f1f5c95.png)

# %% [raw]
#  👉

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 문제 분석과 핵심 요소 추출</h2>
#     &emsp;&#x2022; 목표 상태에 도달하기 위해 수행해야 할 작업을 분석할 수 있다. <br>
#     &emsp;&#x2022; 복잡한 문제 상황에서 문제 해결에 필요한 핵심 요소를 추출할 수 있다.<br>
# </div>

# %% [markdown]
# ### **(1) 문제 분석**

# %% [markdown]
# ![image.png](attachment:48c12126-3dc4-479f-b1e5-4ada720a15e9.png)

# %% [markdown]
# ### **(2) 핵심 요소 추출**

# %% [markdown]
# ![image.png](attachment:df2236e5-bddc-42b2-ad29-511f425ce6cf.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; border-color: #bce8f1;">
#     <div style="font-weight: bold; font-size: 20px">📖 읽기자료</div>
#     <div style="font-weight: bold; font-size: 15px">
#         &ensp; 미래를 예측하기 위한 첫 단계! 핵심 요소 파악하기</div>
#
# </div>

# %% [markdown]
# ![image.png](attachment:e81b3662-3da8-4829-9b1d-6b850d4caf42.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">🤓 탐구 활동:</div>
#     <div style="font-weight: bold; font-size: 17px"> &emsp;생활 속의 다양한 문제 이해하고 분석하기</div>
#     <br>
#     <div style="font-weight: normal; font-size: 14px"> 실생활에서 자신이 경험했던 문제를 생각하고, 이를 분석하여 핵심 요소를 추출해보자.</div>
#     <br>
#
# ![image.png](attachment:fe6d7ed4-8806-4e68-9376-13399ada5de7.png)
#
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>3. 문제 분해와 모델링</h2>
#     &emsp;&#x2022; 문제 분해가 문제 해결과 문제 해결책 탐색에 어떤 유익을 주는지 설명할 수 있다. <br>
#     &emsp;&#x2022; 문제 분해가 문제 해결과 관련된 핵심 요소들을 모델링하는 데 어떤 유익을 주는지 설명할 수 있다.<br>
# </div>

# %% [markdown]
# ### **(1) 문제 해결**

# %% [markdown]
# ![image.png](attachment:e27132d1-dec7-49f5-8944-df322066a9e4.png)

# %% [markdown]
# ### **(2) 모델링**

# %% [markdown]
# ![image.png](attachment:ad0bd43d-b3e3-4d61-a810-d319b2d4c60f.png)
# ![image.png](attachment:2801ece0-ade9-434d-ab35-f2c8ecdc4711.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; border-color: #bce8f1;">
#     <div style="font-weight: bold; font-size: 20px">📖 읽기자료</div>
#     <div style="font-weight: bold; font-size: 15px">
#         &ensp; 나폴레옹과 분할 정복법</div>
#
# </div>

# %% [markdown]
# ![image.png](attachment:4150c190-0b12-4641-887a-c818175c33d6.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">🤓 탐구 활동:</div>
#     <div style="font-weight: bold; font-size: 17px"> &emsp;생활 속 문제를 이해하고 추상화하기</div>
#     <br>
#     <div style="font-weight: normal; font-size: 14px"> 내가 우리 고장 시청의 관광과 직원이라고 가정하고 우리 고장의 특색 있는 시티투어 노선도를 만들어 보자.</div>
#     <br>
#
# </div>

# %% [markdown]
# ![image.png](attachment:44a0ef8b-daf2-4ac2-88f4-e687ddf13595.png)
