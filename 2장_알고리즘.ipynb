# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">문제 해결과 프로그래밍</div>
#     <div style="font-weight: bold; font-size: 20px">2. 알고리즘</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     &#x2022; 알고리즘 설계 <br>
#     &#x2022; 알고리즘 분석<br>
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 생각해보기</div>
#     <br>
# 알고리즘은 왜 필요한 걸까? 알고리즘은 어떻게 설계하고 작성할까?
# </div>

# %% [markdown]
# ![image.png](attachment:49a9f415-52b9-4861-82ce-9cfb80139db2.png)

# %% [markdown]
# **일반화된 지식**
# ✏️ 다양한 제어 구조를 이용하여 알고리즘을 설계하고, 수행 시간의 관점에서 알고리즘을 분석한다

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 알고리즘 설계</h2>
#     &emsp;&#x2022; 제어 구조를 활용하여 논리적이고 효율적인 알고리즘을 설계할 수 있다. <br>
# </div>

# %% [markdown]
# ### **(1) 알고리즘 이해**

# %% [markdown]
# ![image.png](attachment:0bb96a7b-0179-441c-8a5f-a507dc3e3a4a.png)

# %% [markdown]
# ![image.png](attachment:3f5739fc-e8e7-4d84-9c10-9ceb1383c22d.png)

# %% [markdown]
# ### **(2) 알고리즘 표현 방법**

# %% [markdown]
# ![image.png](attachment:65b86bb4-495a-4571-b569-d5645926e6e1.png)

# %% [markdown]
# ![image.png](attachment:b5ef174b-a0a2-457b-b63a-622179f8807a.png)

# %% [markdown]
# ![image.png](attachment:a9e20883-47bd-404a-82fb-59497ac2b989.png)

# %% [markdown]
# ### **(3) 제어 구조**

# %% [markdown]
# ![image.png](attachment:448e3e7f-1cf8-48d8-be59-2524f1f60c4e.png)

# %% [markdown]
# ![image.png](attachment:0f362d4a-d436-44bb-a278-424701cfd90c.png)

# %% [markdown]
# ![image.png](attachment:2b92e76c-2288-4da3-bb5e-d5ea2d409090.png)

# %% [markdown]
# ![image.png](attachment:69c65a95-c40e-4668-a50c-a39b41236c8f.png)

# %% [markdown]
# ![image.png](attachment:5075d4c2-06d4-4764-8b02-0a6504359714.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">🤓 탐구 활동:</div>
#     <div style="font-weight: bold; font-size: 17px"> &emsp;학교 등교 과정을 알고리즘으로 표현하기</div>
#     <br>
#     <div style="font-weight: normal; font-size: 14px"> 등교 과정 중에서 발생할 수 있는 다양한 문제 상황을 제시하고, 문제 해결 방안을 고안하여 알고리즘으로 표현하되, 제시된 제어 구조만을 활용하여 표현해 보자.</div>
#
# </div>

# %% [markdown]
# ![image.png](attachment:6f527b7b-68a7-4dea-b4e3-6f484e3315a2.png)
#
# [영상 자료 링크](https://www.youtube.com/watch?v=PYB32Qx-etk&t=14s)
#
# ![image.png](attachment:681fa656-8170-4aad-ab1d-da021490de8a.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 알고리즘 분석</h2>
#     &emsp;&#x2022; 다양한 알고리즘의 성능을 수행 시간의 관점에서 분석하고 비교할 수 있다.  <br>
# </div>

# %% [markdown]
# ### **(1) 효율적인 알고리즘 선택 방법**

# %% [markdown]
# ![image.png](attachment:330a6280-c47b-4b3d-9bc5-092e02e39694.png)
# ![image.png](attachment:c8ec0425-efe8-4e7a-87c6-8b93209b61f7.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; border-color: #bce8f1;">
#     <div style="font-weight: bold; font-size: 20px">📖 참고자료</div>
#     <div style="font-weight: bold; font-size: 15px">
#         &ensp; 알고리즘 수행 시간 측정</div>
#
# </div>

# %% [markdown]
# ![image.png](attachment:5f2e6009-6110-42cd-b157-9a2b6a468c71.png)

# %% [markdown]
# ### **(2) 알고리즘 수행 시간 측정하기**

# %% [markdown]
# ![image.png](attachment:1d104e98-1004-4d22-a39a-fd6e77f12ea1.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">✏️ 생각해보기</div>
#     <br>
# 만일 1부터 100,000까지 숫자의 합을 구하는 문제라면 두 알고리즘을 적용했을 때 연산 횟수의 차이는 얼마일까?
#     <br>
#
# ![image.png](attachment:4f83513e-d7ad-458b-8888-7fd2ae5aff8d.png)
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc; font-weight: bold;">
#     <div style="font-weight: bold; font-size: 20px">🤓 모둠 활동:</div>
#     <div style="font-weight: bold; font-size: 17px"> &emsp;알고리즘 수행 시간 비교하기</div>
#     <br>
#     <div style="font-weight: bold; font-size: 14px"> 2명씩 모둠을 만들고 각 모둠에서 숫자를 생각하는 학생을 A라 하고 숫자를 맞히는 학생을 B로 정해서 숫자 맞히기 게임을 해 보자. </div>
#     <div style="font-weight: normal; font-size: 14px">
#          * 이 게임은 A가 마음속으로 1부터 20 사이의 임의의 숫자를 정하면
#         B가 A에게 질문을 해 나가면서 그 숫자를 맞히는 게임이다. </div>
#
#
#
# </div>

# %% [markdown]
# ![image.png](attachment:b13d5e40-741f-45dc-8dff-a567212427ee.png)

# %% [markdown]
# ![image.png](attachment:9a700437-e268-4ea9-b0da-41a02424f35d.png)

# %% [markdown]
# ![image.png](attachment:9c998cae-cc94-4706-8434-1074b1df3230.png)
